# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
shop_info_col=['shop_id','city_name','location_id','per_pay','score','comment_cnt','shop_level','cate_1_name','cate_2_name','cate_3_name']

# %%
shop_info=pd.read_csv('../dataset/shop_info.txt',header=None)

# %%
shop_info.columns=shop_info_col

# %%
shop_info.shape
# Out:
# (2000, 10)

# %%
shop_info.head()
# Out:
#    shop_id city_name  location_id  per_pay  score  comment_cnt  shop_level  \
# 0        1        湖州          885        8    4.0         12.0           2
# 1        2       哈尔滨           64       19    NaN          NaN           1
# 2        3        南昌          774        5    3.0          2.0           0
# 3        4        天津          380       18    NaN          NaN           1
# 4        5        杭州          263        2    2.0          2.0           0
#
#   cate_1_name cate_2_name cate_3_name
# 0          美食        休闲茶饮       饮品/甜点
# 1       超市便利店          超市         NaN
# 2          美食        休闲茶饮          奶茶
# 3       超市便利店          超市         NaN
# 4          美食        休闲食品        生鲜水果

# %%
for var in shop_info.columns:
    if var != 'shop_id':        
        print '\n%s'%var
        print shop_info[var].value_counts()
# Out:
# city_name
# 上海     285
# 杭州     225
# 北京     163
# 广州     136
# 南京     130
# 武汉     124
# 深圳      88
# 温州      67
# 苏州      66
# 宁波      45
# 福州      41
# 成都      37
# 厦门      30
# 绍兴      30
# 无锡      26
# 济南      24
# 金华      23
# 青岛      23
# 合肥      21
# 常州      20
# 南昌      19
# 佛山      19
# 重庆      19
# 天津      18
# 西安      17
# 大连      15
# 南宁      15
# 长沙      15
# 郑州      14
# 东莞      13
#       ...
# 宿迁       1
# 张家口      1
# 达州       1
# 信阳       1
# 柳州       1
# 德阳       1
# 葫芦岛      1
# 龙岩       1
# 梧州       1
# 荆门       1
# 聊城       1
# 天门       1
# 荆州       1
# 洛阳       1
# 抚顺       1
# 肇庆       1
# 营口       1
# 濮阳       1
# 清远       1
# 丽水       1
# 东营       1
# 邯郸       1
# 思茅       1
# 汉中       1
# 邢台       1
# 阳江       1
# 锦州       1
# 宝鸡       1
# 保定       1
# 日照       1
# Name: city_name, dtype: int64
#
# location_id
# 680     22
# 399     17
# 552     17
# 1093    15
# 378     14
# 1127    11
# 1032    11
# 554     11
# 485     10
# 642     10
# 924     10
# ...

# %%
shop_info.fillna(-1,inplace=True)

# %%
#sns.distplot(shop_info['location_id'],kde=False)
#sns.distplot(shop_info['per_pay'],kde=False)
#sns.distplot(shop_info['score'],kde=False)
#sns.distplot(shop_info['comment_cnt'],kde=False)
#sns.distplot(shop_info['shop_level'],kde=False)

# %%
sns.pairplot(shop_info[['location_id','per_pay','score','comment_cnt','shop_level']],hue='shop_level')
